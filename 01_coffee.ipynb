# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("coffee_cognition_synthetic_dataset.csv")
df.head()
# Out:
#   Participant_ID  Age  Gender Brewing_Method Time_of_Day  Caffeine_mg  \
# 0          P1000   56  Female           Drip     Morning   128.698060
# 1          P1001   46  Female      Pour Over     Morning   144.738069
# 2          P1002   32  Female           Drip   Afternoon   179.502409
# 3          P1003   25  Female           Drip     Morning   152.313091
# 4          P1004   38  Female      Pour Over   Afternoon    69.942719
#
#    Sleep_Hours  Sleep_Quality_Score  Stress_Level  Physical_Activity_Level  \
# 0     7.581691             7.137768      3.591877                 8.662958
# 1     9.000000             7.003487      3.592791                 7.523608
# 2     8.421774             6.733141      3.361499                 8.564198
# 3     7.356962            10.000000      1.626963                 6.233739
# 4     6.104359             6.063791      4.539595                 6.633885
#
#    Stroop_Reaction_Time_ms  N_Back_Accuracy  PVT_Reaction_Time_ms  Focus_Level
# 0               510.566306         0.980000            281.727137     0.978034
# 1               487.581412         0.980000            191.029917     0.247670
# 2               505.235389         0.980000            218.402429     0.238690
# 3               507.385556         0.980000            204.185196     1.000000
# 4               659.780967         0.705424            289.089974     0.590769

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Participant_ID           280 non-null    object
#  1   Age                      280 non-null    int64
#  2   Gender                   280 non-null    object
#  3   Brewing_Method           280 non-null    object
#  4   Time_of_Day              280 non-null    object
#  5   Caffeine_mg              280 non-null    float64
#  6   Sleep_Hours              280 non-null    float64
#  7   Sleep_Quality_Score      280 non-null    float64
#  8   Stress_Level             280 non-null    float64
#  9   Physical_Activity_Level  280 non-null    float64
#  10  Stroop_Reaction_Time_ms  280 non-null    float64
#  11  N_Back_Accuracy          280 non-null    float64
#  12  PVT_Reaction_Time_ms     280 non-null    float64
#  13  Focus_Level              280 non-null    float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 30.8+ KB

# %%
df.describe()
# Out:
#               Age  Caffeine_mg  Sleep_Hours  Sleep_Quality_Score  \
# count  280.000000   280.000000   280.000000           280.000000
# mean    38.925000   159.732931     6.880236             6.511163
# std     12.531455    65.230342     1.229413             1.464201
# min     18.000000    16.008605     3.668190             2.000000
# 25%     28.000000   114.192392     6.045335             5.596004
# 50%     40.000000   152.348796     6.881735             6.597678
# 75%     50.000000   201.684690     7.839216             7.523202
# max     59.000000   340.042300     9.000000            10.000000
#
#        Stress_Level  Physical_Activity_Level  Stroop_Reaction_Time_ms  \
# count    280.000000               280.000000               280.000000
# mean       5.455406                 6.039493               575.320576
# std        1.868623                 1.881540                64.139574
# min        1.000000                 1.000000               338.410012
# 25%        4.150939                 4.723796               536.965002
# 50%        5.375658                 6.165846               574.497494
# 75%        6.666039                 7.270508               615.511895
# max       10.000000                10.000000               752.837387
#
#        N_Back_Accuracy  PVT_Reaction_Time_ms  Focus_Level
# count       280.000000            280.000000   280.000000
# mean          0.880620            249.481723     0.829735
# std           0.114265             38.152326     0.165093
# min           0.495845            122.280901     0.230499
# 25%           0.804228            225.764259     0.726995
# 50%           0.918909            250.588707     0.856856
# 75%           0.980000            276.050323     0.988236
# max           0.980000            334.556624     1.000000

# %%
df.isna().sum()
# Out:
# Participant_ID             0
# Age                        0
# Gender                     0
# Brewing_Method             0
# Time_of_Day                0
# Caffeine_mg                0
# Sleep_Hours                0
# Sleep_Quality_Score        0
# Stress_Level               0
# Physical_Activity_Level    0
# Stroop_Reaction_Time_ms    0
# N_Back_Accuracy            0
# PVT_Reaction_Time_ms       0
# Focus_Level                0
# dtype: int64

# %%
df['Brewing_Method'].value_counts()
# Out:
# Brewing_Method
# Drip            70
# Espresso        63
# Pour Over       61
# French Press    59
# Cold Brew       27
# Name: count, dtype: int64

# %%
plt.figure()
sns.countplot(data=df,x='Brewing_Method')
plt.xticks(rotation=45)
plt.title('Brewing Method Distribution')
plt.show()

# %%
plt.figure()
sns.countplot(data=df, x="Time_of_Day")
plt.title("Time of Day")
plt.show()

# %%
sns.scatterplot(
    x="Caffeine_mg",
    y="Stroop_Reaction_Time_ms",
    data=df
)
plt.title("Caffeine vs Stroop Reaction Time")
plt.show()

# %%
sns.regplot(
    x="Caffeine_mg",
    y="Stroop_Reaction_Time_ms",
    data=df,
    scatter=False,
    color="red"
)

plt.title("Caffeine Intake vs Stroop Reaction Time")
plt.xlabel("Caffeine (mg)")
plt.ylabel("Stroop Reaction Time (ms)")
plt.show()

# %%
sns.regplot(x="Caffeine_mg", y="Focus_Level", data=df, scatter=False, color='red')
plt.title("Caffeine mg vs Focus Level")
plt.xlabel("Caffeine mg")
plt.ylabel("Focus Level")
plt.show()

# %%
sns.scatterplot(
    x="Sleep_Quality_Score",
    y="N_Back_Accuracy",
    data=df
)
plt.title("Sleep Quality vs Working Memory Accuracy")
plt.show()

# %%
numeric_cols = [
    "Age", "Caffeine_mg", "Sleep_Hours",
    "Sleep_Quality_Score", "Stress_Level",
    "Physical_Activity_Level",
    "Stroop_Reaction_Time_ms",
    "PVT_Reaction_Time_ms",
    "N_Back_Accuracy",
    "Focus_Level"
]

plt.figure(figsize=(10,10))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix of Key Variables")
plt.show()
